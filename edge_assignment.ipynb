# %% [markdown]
# **Libraries Imported**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Load the dataset**

# %%
file_path = "/content/drive/MyDrive/Colab Notebooks/EDGE Assignment/Medicaldataset.csv"
df = pd.read_csv(file_path)
df.sample(5)
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 140    45       0          79                       87
# 1241   70       0          72                      104
# 1035   50       1          74                      208
# 877    60       1          94                      122
# 295    63       0          74                      119
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 140                         47         82.0   2.38     0.003  negative
# 1241                        65        154.0   1.67     1.630  positive
# 1035                       100        244.0   3.20     0.008  negative
# 877                         67        115.0   2.10     2.200  positive
# 295                         78        103.0   2.98     0.008  negative

# %% [markdown]
# **Showing first 10 rows**

# %%
df.head(10)
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
# 5   58       0          61                      112                        58
# 6   32       0          40                      179                        68
# 7   63       1          60                      214                        82
# 8   44       0          60                      154                        81
# 9   67       1          61                      160                        95
#
#    Blood sugar   CK-MB  Troponin    Result
# 0        160.0    1.80     0.012  negative
# ...

# %% [markdown]
# **Showing Last 10 rows**

# %%
df.tail(10)
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 1309   47       1          94                      105
# 1310   70       0          80                      135
# 1311   85       1         112                      115
# 1312   48       1          84                      118
# 1313   86       0          40                      179
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 1309                        81        135.0  36.24     0.263  positive
# 1310                        75        351.0   2.21    10.000  positive
# 1311                        69        114.0   2.19     0.062  positive
# 1312                        68         96.0   5.33     0.006  negative
# ...

# %% [markdown]
# **Info parameters Show**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %% [markdown]
# **Data Quality Report Show**

# %%
df.describe()
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.191812     0.659591    78.336619               127.170584
# std      13.647315     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# ...

# %% [markdown]
# **Library Imported**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Dataset Loded**

# %%
file_path = "/content/drive/MyDrive/Colab Notebooks/EDGE Assignment/Crop_recommendation.csv"
df = pd.read_csv(file_path)
df.sample(5)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall        label
# 616    19  53  22    27.864013  80.451314  6.852885   42.830539     mungbean
# 971    32  14  37    22.730313  88.485679  6.825256  104.684324  pomegranate
# 27     97  50  41    24.529227  80.544986  7.070960  260.263403         rice
# 1078  118  88  51    25.449262  79.492220  6.201912  100.661917       banana
# 259    20  79  77    18.549886  16.025427  7.648675   76.325652     chickpea

# %% [markdown]
# **Creating Scatter Plots for every Numeric Features**

# %%
sns.pairplot(df, hue = 'label', palette = 'Paired')
plt.show()

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117
